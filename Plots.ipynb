# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results.csv")

# %%
df[df['layer'] == 2]
# Out:
#     layer  head   bleu
# 8       2     1  39.38
# 9       2     2  39.91
# 10      2     4  39.90
# 11      2     8  39.97
# 12      2    16  40.03
# 13      2    32  39.64
# 14      2    64  39.45
# 15      2   128  40.01

# %%
grid = sns.FacetGrid(df, col="layer", hue="layer", palette="tab10", col_wrap=2, height=5)
grid.map(plt.plot, "head", "bleu", marker="o")

# Adjust the tick positions and labels
grid.set(xticks=df['head'].unique(), ylim=(39,41))

# %%
g = sns.relplot(data=df, x="head", y="bleu", hue="layer", palette="tab10", markers="x")
g.set_xticklabels(df['head'].unique())
g.set_ylim(38,41)
g
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-5a2b45819d0f> in <module>
#       1 g = sns.relplot(data=df, x="head", y="bleu", hue="layer", palette="tab10", markers="x")
# ----> 2 g.set_xticklabels(df['head'].unique())
#       3 g.set_ylim(38,41)
#       4 g
#
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py in set_xticklabels(self, labels, step, **kwargs)
#     850                 ax.set_xticklabels(curr_labels, **kwargs)
#     851             else:
# --> 852                 ax.set_xticklabels(labels, **kwargs)
#     853         return self
#     854
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ...
